# %%
import pandas as pd
import numpy as np
import os

# %%
# combine all 5 csv happiness files into one.
hp2015 = pd.read_csv("csv_files/2015.csv")
hp2016 = pd.read_csv("csv_files/2016.csv")
hp2017 = pd.read_csv("csv_files/2017.csv")
hp2018 = pd.read_csv("csv_files/2018.csv")
hp2019 = pd.read_csv("csv_files/2019.csv")

# %%
#columns wanted:
# 'Country', 'Region', 'Happiness Rank', 'Happiness Score','Standard Error', 'Economy (GDP per Capita)', 'Family',
# 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
# 'Generosity', 'Dystopia Residual'

# %%
# Step 1: cleaning column names
# country column : change 2019 "country or region" to "country" - 'Canada', 'Germany', 'Russia', 'Brazil', 'UK', 'India', 'Australia', 'China', 'USA', 'Japan'
# rank coloum: stadardize column names. use "happiness_rank"
# score coloum: stadardize column names. use "happiness_score"
# Economy (GDP per Capita): standardize column names. use "gdp"
# Trust colomn : standardize column names. use "trust_in_government"
# Step 2: add new column of year.

# %% [markdown]
# ## HP 2015

# %%
hp2015a = hp2015.copy()

# %%
hp2015a = hp2015a.drop(columns=['Region', 'Standard Error', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Generosity', 'Dystopia Residual', 'Happiness Rank'])

# %%
hp2015a = hp2015a.rename(columns={
    'Country': 'country',
    'Happiness Score': 'happiness_score',
    'Economy (GDP per Capita)': 'gdp',
    'Trust (Government Corruption)': 'trust_in_government',
})

# %%
hp2015a['year'] = 2015

# %%
hp2015a
# Out:
#          country  happiness_score      gdp  trust_in_government  year
# 0    Switzerland            7.587  1.39651              0.41978  2015
# 1        Iceland            7.561  1.30232              0.14145  2015
# 2        Denmark            7.527  1.32548              0.48357  2015
# 3         Norway            7.522  1.45900              0.36503  2015
# 4         Canada            7.427  1.32629              0.32957  2015
# ..           ...              ...      ...                  ...   ...
# 153       Rwanda            3.465  0.22208              0.55191  2015
# 154        Benin            3.340  0.28665              0.08010  2015
# 155        Syria            3.006  0.66320              0.18906  2015
# 156      Burundi            2.905  0.01530              0.10062  2015
# 157         Togo            2.839  0.20868              0.10731  2015
#
# [158 rows x 5 columns]

# %% [markdown]
# ## HP 2016

# %%
hp2016a = hp2016.copy()

# %%
hp2016a
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
hp2016a = hp2016a.drop(columns=['Region','Lower Confidence Interval','Upper Confidence Interval', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Generosity', 'Dystopia Residual', 'Happiness Rank'])

# %%
hp2016a = hp2016a.rename(columns={
    'Country': 'country',
    'Happiness Score': 'happiness_score',
    'Economy (GDP per Capita)': 'gdp',
    'Trust (Government Corruption)': 'trust_in_government',
})

# %%
hp2016a['year'] = 2016

# %%
hp2016a
# Out:
#          country  happiness_score      gdp  trust_in_government  year
# 0        Denmark            7.526  1.44178              0.44453  2016
# 1    Switzerland            7.509  1.52733              0.41203  2016
# 2        Iceland            7.501  1.42666              0.14975  2016
# 3         Norway            7.498  1.57744              0.35776  2016
# 4        Finland            7.413  1.40598              0.41004  2016
# ..           ...              ...      ...                  ...   ...
# 152        Benin            3.484  0.39499              0.06681  2016
# 153  Afghanistan            3.360  0.38227              0.07112  2016
# 154         Togo            3.303  0.28123              0.11587  2016
# 155        Syria            3.069  0.74719              0.17233  2016
# 156      Burundi            2.905  0.06831              0.09419  2016
#
# [157 rows x 5 columns]

# %% [markdown]
# ## HP 2017

# %%
hp2017a = hp2017.copy()

# %%
hp2017a
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
hp2017a = hp2017a.drop(columns=['Whisker.high','Whisker.low', 'Family', 'Health..Life.Expectancy.', 'Freedom', 'Generosity', 'Dystopia.Residual', 'Happiness.Rank'])

# %%
hp2017a = hp2017a.rename(columns={
    'Country': 'country',
    'Happiness.Score': 'happiness_score',
    'Economy..GDP.per.Capita.': 'gdp',
    'Trust..Government.Corruption.': 'trust_in_government',
})

# %%
hp2017a['year'] = 2017

# %%
hp2017a
# Out:
#                       country  happiness_score       gdp  trust_in_government  \
# 0                      Norway            7.537  1.616463             0.315964
# 1                     Denmark            7.522  1.482383             0.400770
# 2                     Iceland            7.504  1.480633             0.153527
# 3                 Switzerland            7.494  1.564980             0.367007
# 4                     Finland            7.469  1.443572             0.382612
# ..                        ...              ...       ...                  ...
# 150                    Rwanda            3.471  0.368746             0.455220
# 151                     Syria            3.462  0.777153             0.151347
# 152                  Tanzania            3.349  0.511136             0.066035
# 153                   Burundi            2.905  0.091623             0.084148
# 154  Central African Republic            2.693  0.000000             0.056565
#
#      year
# 0    2017
# ...

# %% [markdown]
# ## HP 2018

# %%
hp2018a = hp2018.copy()

# %%
hp2018a
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
hp2018a = hp2018a.drop(columns=['Overall rank','Social support', 'Freedom to make life choices', 'Generosity', 'Healthy life expectancy'])

# %%
hp2018a = hp2018a.rename(columns={
    'Country or region': 'country',
    'Score': 'happiness_score',
    'GDP per capita': 'gdp',
    'Perceptions of corruption': 'trust_in_government',
})

# %%
hp2018a
# Out:
#                       country  happiness_score    gdp  trust_in_government
# 0                     Finland            7.632  1.305                0.393
# 1                      Norway            7.594  1.456                0.340
# 2                     Denmark            7.555  1.351                0.408
# 3                     Iceland            7.495  1.343                0.138
# 4                 Switzerland            7.487  1.420                0.357
# ..                        ...              ...    ...                  ...
# 151                     Yemen            3.355  0.442                0.064
# 152                  Tanzania            3.303  0.455                0.097
# 153               South Sudan            3.254  0.337                0.106
# 154  Central African Republic            3.083  0.024                0.038
# 155                   Burundi            2.905  0.091                0.076
#
# [156 rows x 4 columns]

# %%
hp2018a['year'] = 2018

# %%
hp2018a
# Out:
#                       country  happiness_score    gdp  trust_in_government  \
# 0                     Finland            7.632  1.305                0.393
# 1                      Norway            7.594  1.456                0.340
# 2                     Denmark            7.555  1.351                0.408
# 3                     Iceland            7.495  1.343                0.138
# 4                 Switzerland            7.487  1.420                0.357
# ..                        ...              ...    ...                  ...
# 151                     Yemen            3.355  0.442                0.064
# 152                  Tanzania            3.303  0.455                0.097
# 153               South Sudan            3.254  0.337                0.106
# 154  Central African Republic            3.083  0.024                0.038
# 155                   Burundi            2.905  0.091                0.076
#
#      year
# 0    2018
# 1    2018
# 2    2018
# 3    2018
# ...

# %% [markdown]
# ## HP 2019

# %%
hp2019a = hp2019.copy()

# %%
hp2019a
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
hp2019a = hp2019a.drop(columns=['Overall rank','Social support', 'Freedom to make life choices', 'Generosity', 'Healthy life expectancy'])

# %%
hp2019a = hp2019a.rename(columns={
    'Country or region': 'country',
    'Score': 'happiness_score',
    'GDP per capita': 'gdp',
    'Perceptions of corruption': 'trust_in_government',
})

# %%
hp2019a['year'] = 2019

# %%
hp2019a
# Out:
#                       country  happiness_score    gdp  trust_in_government  \
# 0                     Finland            7.769  1.340                0.393
# 1                     Denmark            7.600  1.383                0.410
# 2                      Norway            7.554  1.488                0.341
# 3                     Iceland            7.494  1.380                0.118
# 4                 Netherlands            7.488  1.396                0.298
# ..                        ...              ...    ...                  ...
# 151                    Rwanda            3.334  0.359                0.411
# 152                  Tanzania            3.231  0.476                0.147
# 153               Afghanistan            3.203  0.350                0.025
# 154  Central African Republic            3.083  0.026                0.035
# 155               South Sudan            2.853  0.306                0.091
#
#      year
# 0    2019
# 1    2019
# 2    2019
# 3    2019
# ...

# %% [markdown]
# ## DataSets Concact

# %%
""""
hp2019a
hp2018a
hp2017a
hp2016a
hp2015a

""""

# %%
hp_2015_2019 = pd.concat([hp2015a, hp2016a, hp2017a, hp2018a, hp2019a], axis=0)

# %%
hp_2015_2019.reindex['country', 'year', 'happiness_score', 'gdp', 'trust_in_government']

# %%
hp_2015_2019
# Out:
#                       country  happiness_score      gdp  trust_in_government  \
# 0                 Switzerland            7.587  1.39651              0.41978
# 1                     Iceland            7.561  1.30232              0.14145
# 2                     Denmark            7.527  1.32548              0.48357
# 3                      Norway            7.522  1.45900              0.36503
# 4                      Canada            7.427  1.32629              0.32957
# ..                        ...              ...      ...                  ...
# 151                    Rwanda            3.334  0.35900              0.41100
# 152                  Tanzania            3.231  0.47600              0.14700
# 153               Afghanistan            3.203  0.35000              0.02500
# 154  Central African Republic            3.083  0.02600              0.03500
# 155               South Sudan            2.853  0.30600              0.09100
#
#      year
# 0    2015
# 1    2015
# ...
