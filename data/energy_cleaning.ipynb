# %%
import pandas as pd
import numpy as np
import os

# %%
energy = pd.read_csv("csv_files/global_energy_consumption.csv")

# %%
energy
# Out:
#       Country  Year  Total Energy Consumption (TWh)  \
# 0      Canada  2018                         9525.38
# 1     Germany  2020                         7922.08
# 2      Russia  2002                         6630.01
# 3      Brazil  2010                         8580.19
# 4      Canada  2006                          848.88
# ...       ...   ...                             ...
# 9995   Canada  2017                         9786.50
# 9996       UK  2011                         7200.88
# 9997    India  2011                         2579.82
# 9998       UK  2020                         5950.39
# 9999   Brazil  2018                         5387.71
#
#       Per Capita Energy Use (kWh)  Renewable Energy Share (%)  \
# 0                        42301.43                       13.70
# 1                        36601.38                       33.63
# 2                        41670.20                       10.82
# 3                        10969.58                       73.24
# ...

# %%
# Delete rows that are not in the range of 2015-2019

# %%
energy['Country'].unique()
# Out:
# array(['Canada', 'Germany', 'Russia', 'Brazil', 'UK', 'India',
#        'Australia', 'China', 'USA', 'Japan'], dtype=object)
